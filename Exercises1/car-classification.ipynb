# %% [markdown]
# # Exercitiu #1
# Folosind datasetul de la Auto MPG, trebuie sa implementam un model de clasificare care va trebui sa clasifice masinile in functie de eficienta consumului de combustibil.
# <br><br>
# Fiind o variabila de tip continuu, va trebui sa discretizam _MPG_ pe 3 intervale/clase posibile - low, medium & high efficiency.
# Vom urma urmatorii pasi:
# 1. Rescriem coloana _MPG_ incat sa contina un integer asociat cu clasa de eficienta
# 2. Preprocesam datele de intrare
# 3. Construim si antrenam modelul
# 4. Testam modelul si evaluam rezultatele

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
np.set_printoptions(precision=3, suppress=True)
print("TensorFlow version installed: ", tf.__version__)
# Out:
# TensorFlow version installed:  2.12.0

# %%
url = 'http://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data' # url-ul din care vom prelua datasetul
columns = ['MPG', 'Cylinders', 'Displacement', 'Horsepower', 'Weight', 'Acceleration', 'Model Year', 'Origin'] # atributele din dataset
classes = ['LOW', 'MED', 'HIGH'] # clasele de eficienta de consum al combustibilului

rawDataset = pd.read_csv(url, names=columns, na_values = '?', comment='\t', sep=' ', skipinitialspace=True) # citim datele
dataset = rawDataset.copy()
dataset = dataset.dropna()
dataset = dataset.drop(columns=['Origin']) # nu vom folosi regiunea de origine a masinii in predictia clasei de eficienta
dataset.tail()
# Out:
#       MPG  Cylinders  Displacement  Horsepower  Weight  Acceleration  \
# 393  27.0          4         140.0        86.0  2790.0          15.6
# 394  44.0          4          97.0        52.0  2130.0          24.6
# 395  32.0          4         135.0        84.0  2295.0          11.6
# 396  28.0          4         120.0        79.0  2625.0          18.6
# 397  31.0          4         119.0        82.0  2720.0          19.4
#
#      Model Year
# 393          82
# 394          82
# 395          82
# 396          82
# 397          82

# %%
lims = [0, 20, 30, float("inf")] # setam breakpoint-urile
labels = [0, 1, 2] # setam label-urile numerice pentru clasele de eficienta
dataset['Efficiency'] = pd.cut(dataset['MPG'], bins=lims, labels=labels, right=False) # construim o noua coloana pentru clasa de eficienta
dataset = dataset.drop(columns=['MPG']) # stergem coloana de MPG - nu o vom folosi

# %% [markdown]
# ^ Am creat 4 breakpoint-uri pentru a clasifica masinile in functie de consumul de combustibil:
# - [0, 20) - LOW efficiency | daca 0 <= MPG < 20 atunci consideram ca modelul masinii este ineficient
# - [20, 30) - MED efficiency | daca 20 <= MPG < 30 atunci eficienta este medie
# - [30, +$\infty$) - HIGH efficiency | daca MPG >= 30 atunci eficienra masinii este mare
#
# <br><br>
# Observatii:<br>
# - float("inf") reprezinta +$\infty$
# - numerele 0, 1, 2 vor fi asociate mai tarziu claselor LOW, MED, HIGH

# %%
dataset.tail()
# Out:
#      Cylinders  Displacement  Horsepower  Weight  Acceleration  Model Year  \
# 393          4         140.0        86.0  2790.0          15.6          82
# 394          4          97.0        52.0  2130.0          24.6          82
# 395          4         135.0        84.0  2295.0          11.6          82
# 396          4         120.0        79.0  2625.0          18.6          82
# 397          4         119.0        82.0  2720.0          19.4          82
#
#     Efficiency
# 393          1
# 394          2
# 395          2
# 396          1
# 397          2

# %%
toNormalize = ['Cylinders', 'Displacement', 'Horsepower', 'Weight', 'Acceleration', 'Model Year'] # vector cu coloanele pe care le vom normaliza
for column in toNormalize:
    dataset[column] = pd.to_numeric(dataset[column])
    dataset[column] = (dataset[column] - dataset[column].min()) / (dataset[column].max() - dataset[column].min())

# %% [markdown]
# ^ normalizam valorile din coloanele folosite. De data asta, am facut normalizare manual, cu formula urmatoare:
# $$
# x_{i_{norm}} = \frac{x_i - min(D)}{max(D) - min(D)}, \quad i \in (0, n-1),\quad n = card(D)
# $$
# unde $D$ - o coloana din dataset (o multime finita de valori)<br><br>
# Astfel mapam valorile tuturor atributelor pe intervalul (0, 1) - cea mai buna varianta cand lucram cu modele de ML.

# %%
dataset.tail()
# Out:
#      Cylinders  Displacement  Horsepower    Weight  Acceleration  Model Year  \
# 393        0.2      0.186047    0.217391  0.333711      0.452381         1.0
# 394        0.2      0.074935    0.032609  0.146583      0.988095         1.0
# 395        0.2      0.173127    0.206522  0.193365      0.214286         1.0
# 396        0.2      0.134367    0.179348  0.286929      0.630952         1.0
# 397        0.2      0.131783    0.195652  0.313864      0.678571         1.0
#
#     Efficiency
# 393          1
# 394          2
# 395          2
# 396          1
# 397          2

# %%
trainSet = dataset.sample(frac=0.8, random_state=0) # separam 80% pentru antrenare
testSet = dataset.drop(trainSet.index) # restul ramane pentru testare

# %%
trainFeatures = trainSet.copy()
testFeatures = testSet.copy()
trainLabels = trainFeatures.pop("Efficiency")
testLabels = testFeatures.pop("Efficiency")

# %% [markdown]
# ^ este necesar sa separam atributele pe care le stim (**Features**) de atributul pe care vrem ca modelul sa invete sa il prezica (**Label** sau **Target**).<br><br>
# Chiar si cand antrenam modelul, trebuie sa existe separarea asta: ii dam modelului datele, si apoi ii spunem carui fel de clasa apartin datele respective, ca apoi sa poata prezica clasa avand acces doar la date fara labels.

# %%
trainLabels = trainLabels.map({0: "LOW", 1: "MED", 2:"HIGH"})
trainLabels = pd.get_dummies(trainLabels).astype(np.float32).values
testLabels = testLabels.map({0: "LOW", 1: "MED", 2:"HIGH"})
testLabels = pd.get_dummies(testLabels).astype(np.float32).values

# %%
model = tf.keras.Sequential([
    #normalizer,                deoarece am facut normalizarea manual, nu mai avem nevoie de un strat de preprocesare
    tf.keras.layers.Flatten(input_shape=(6,)), # in schimb, trebuie sa definim un strat de input care va preia atributele cunoscute (care sunt 6 in total)
    tf.keras.layers.Dense(64, activation="relu"),
    tf.keras.layers.Dense(64, activation="relu"),
    tf.keras.layers.Dense(32, activation="relu"),
    tf.keras.layers.Dense(3, activation="softmax") # avem nevoie de 3 neuroni in stratul de output deoarece exista 3 clase posibile
])

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.005), 
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
# %%time
history = model.fit(trainFeatures, trainLabels, epochs=100, validation_split=0.2, batch_size=8)
# Out:
# Epoch 1/100
# 32/32 [==============================] - 1s 15ms/step - loss: 0.7322 - accuracy: 0.6175 - val_loss: 0.5212 - val_accuracy: 0.8254
# Epoch 2/100
# 32/32 [==============================] - 0s 9ms/step - loss: 0.5045 - accuracy: 0.7968 - val_loss: 0.4994 - val_accuracy: 0.8095
# Epoch 3/100
# 32/32 [==============================] - 0s 10ms/step - loss: 0.4433 - accuracy: 0.8167 - val_loss: 0.5244 - val_accuracy: 0.8254
# Epoch 4/100
# 32/32 [==============================] - 0s 11ms/step - loss: 0.4151 - accuracy: 0.8167 - val_loss: 0.4645 - val_accuracy: 0.8254
# Epoch 5/100
# 32/32 [==============================] - 0s 9ms/step - loss: 0.4148 - accuracy: 0.8446 - val_loss: 0.6487 - val_accuracy: 0.7778
# Epoch 6/100
# 32/32 [==============================] - 0s 10ms/step - loss: 0.4076 - accuracy: 0.8367 - val_loss: 0.4494 - val_accuracy: 0.8095
# Epoch 7/100
# 32/32 [==============================] - 0s 11ms/step - loss: 0.4040 - accuracy: 0.8327 - val_loss: 0.4526 - val_accuracy: 0.8095
# Epoch 8/100
# 32/32 [==============================] - 0s 9ms/step - loss: 0.4048 - accuracy: 0.8446 - val_loss: 0.4763 - val_accuracy: 0.8095
# Epoch 9/100
# 32/32 [==============================] - 0s 11ms/step - loss: 0.3697 - accuracy: 0.8406 - val_loss: 0.4583 - val_accuracy: 0.8413
# Epoch 10/100
# 32/32 [==============================] - 0s 10ms/step - loss: 0.3571 - accuracy: 0.8566 - val_loss: 0.4865 - val_accuracy: 0.8413
# Epoch 11/100
# 32/32 [==============================] - 0s 9ms/step - loss: 0.3548 - accuracy: 0.8486 - val_loss: 0.4782 - val_accuracy: 0.8413
# Epoch 12/100
# 32/32 [==============================] - 0s 11ms/step - loss: 0.3847 - accuracy: 0.8446 - val_loss: 0.4601 - val_accuracy: 0.8254
# Epoch 13/100
# 32/32 [==============================] - 0s 11ms/step - loss: 0.3762 - accuracy: 0.8406 - val_loss: 0.5036 - val_accuracy: 0.8571
# Epoch 14/100
# 32/32 [==============================] - 0s 11ms/step - loss: 0.3542 - accuracy: 0.8685 - val_loss: 0.5370 - val_accuracy: 0.7460
# Epoch 15/100
# 32/32 [==============================] - 0s 11ms/step - loss: 0.3410 - accuracy: 0.8725 - val_loss: 0.4764 - val_accuracy: 0.8254
# Epoch 16/100
# 32/32 [==============================] - 0s 10ms/step - loss: 0.3362 - accuracy: 0.8725 - val_loss: 0.4685 - val_accuracy: 0.8095
# Epoch 17/100
# 32/32 [==============================] - 0s 11ms/step - loss: 0.3496 - accuracy: 0.8526 - val_loss: 0.5545 - val_accuracy: 0.7778
# Epoch 18/100
# 32/32 [==============================] - 0s 11ms/step - loss: 0.3986 - accuracy: 0.8367 - val_loss: 0.4661 - val_accuracy: 0.8254
# Epoch 19/100
# 32/32 [==============================] - 0s 11ms/step - loss: 0.3449 - accuracy: 0.8446 - val_loss: 0.4781 - val_accuracy: 0.8254
# Epoch 20/100
# 32/32 [==============================] - 0s 10ms/step - loss: 0.3447 - accuracy: 0.8685 - val_loss: 0.5717 - val_accuracy: 0.7937
# Epoch 21/100
# 32/32 [==============================] - 0s 11ms/step - loss: 0.3444 - accuracy: 0.8486 - val_loss: 0.4829 - val_accuracy: 0.8095
# Epoch 22/100
# 32/32 [==============================] - 0s 13ms/step - loss: 0.3482 - accuracy: 0.8606 - val_loss: 0.5315 - val_accuracy: 0.8413
# Epoch 23/100
# 32/32 [==============================] - 0s 10ms/step - loss: 0.3725 - accuracy: 0.8327 - val_loss: 0.4948 - val_accuracy: 0.8413
# Epoch 24/100
# 32/32 [==============================] - 0s 11ms/step - loss: 0.3407 - accuracy: 0.8566 - val_loss: 0.5153 - val_accuracy: 0.8254
# Epoch 25/100
# 32/32 [==============================] - 0s 9ms/step - loss: 0.3190 - accuracy: 0.8725 - val_loss: 0.5064 - val_accuracy: 0.8254
# Epoch 26/100
# 32/32 [==============================] - 0s 8ms/step - loss: 0.3275 - accuracy: 0.8645 - val_loss: 0.4615 - val_accuracy: 0.8095
# Epoch 27/100
# 32/32 [==============================] - 0s 11ms/step - loss: 0.3287 - accuracy: 0.8685 - val_loss: 0.5222 - val_accuracy: 0.8730
# Epoch 28/100
# 32/32 [==============================] - 0s 9ms/step - loss: 0.3455 - accuracy: 0.8446 - val_loss: 0.4877 - val_accuracy: 0.8095
# Epoch 29/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.3546 - accuracy: 0.8645 - val_loss: 0.4876 - val_accuracy: 0.8095
# Epoch 30/100
# 32/32 [==============================] - 0s 9ms/step - loss: 0.3427 - accuracy: 0.8566 - val_loss: 0.4931 - val_accuracy: 0.8413
# Epoch 31/100
# 32/32 [==============================] - 0s 9ms/step - loss: 0.3494 - accuracy: 0.8685 - val_loss: 0.4340 - val_accuracy: 0.8254
# Epoch 32/100
# 32/32 [==============================] - 0s 10ms/step - loss: 0.3418 - accuracy: 0.8446 - val_loss: 0.4928 - val_accuracy: 0.8254
# Epoch 33/100
# 32/32 [==============================] - 0s 15ms/step - loss: 0.3732 - accuracy: 0.8446 - val_loss: 0.4557 - val_accuracy: 0.8413
# Epoch 34/100
# 32/32 [==============================] - 0s 11ms/step - loss: 0.3468 - accuracy: 0.8725 - val_loss: 0.4661 - val_accuracy: 0.8254
# Epoch 35/100
# 32/32 [==============================] - 0s 14ms/step - loss: 0.3235 - accuracy: 0.8725 - val_loss: 0.5893 - val_accuracy: 0.7778
# Epoch 36/100
# 32/32 [==============================] - 0s 9ms/step - loss: 0.4082 - accuracy: 0.8406 - val_loss: 0.5103 - val_accuracy: 0.7778
# Epoch 37/100
# 32/32 [==============================] - 0s 10ms/step - loss: 0.3540 - accuracy: 0.8406 - val_loss: 0.4582 - val_accuracy: 0.8095
# Epoch 38/100
# 32/32 [==============================] - 0s 11ms/step - loss: 0.3540 - accuracy: 0.8566 - val_loss: 0.4600 - val_accuracy: 0.8095
# Epoch 39/100
# 32/32 [==============================] - 0s 10ms/step - loss: 0.3283 - accuracy: 0.8725 - val_loss: 0.4813 - val_accuracy: 0.8095
# Epoch 40/100
# 32/32 [==============================] - 0s 13ms/step - loss: 0.3283 - accuracy: 0.8765 - val_loss: 0.4936 - val_accuracy: 0.7937
# Epoch 41/100
# 32/32 [==============================] - 0s 11ms/step - loss: 0.3430 - accuracy: 0.8486 - val_loss: 0.5386 - val_accuracy: 0.7778
# Epoch 42/100
# 32/32 [==============================] - 1s 16ms/step - loss: 0.3237 - accuracy: 0.8685 - val_loss: 0.5117 - val_accuracy: 0.8095
# Epoch 43/100
# 32/32 [==============================] - 0s 11ms/step - loss: 0.3202 - accuracy: 0.8685 - val_loss: 0.4879 - val_accuracy: 0.8254
# Epoch 44/100
# 32/32 [==============================] - 0s 11ms/step - loss: 0.3109 - accuracy: 0.8486 - val_loss: 0.5032 - val_accuracy: 0.8095
# Epoch 45/100
# 32/32 [==============================] - 0s 9ms/step - loss: 0.3205 - accuracy: 0.8566 - val_loss: 0.5476 - val_accuracy: 0.8413
# Epoch 46/100
# 32/32 [==============================] - 0s 11ms/step - loss: 0.3153 - accuracy: 0.8486 - val_loss: 0.5581 - val_accuracy: 0.7937
# Epoch 47/100
# 32/32 [==============================] - 0s 13ms/step - loss: 0.3271 - accuracy: 0.8685 - val_loss: 0.5061 - val_accuracy: 0.8254
# Epoch 48/100
# 32/32 [==============================] - 0s 11ms/step - loss: 0.3322 - accuracy: 0.8645 - val_loss: 0.5668 - val_accuracy: 0.8413
# Epoch 49/100
# 32/32 [==============================] - 0s 11ms/step - loss: 0.3146 - accuracy: 0.8606 - val_loss: 0.5025 - val_accuracy: 0.8095
# Epoch 50/100
# 32/32 [==============================] - 0s 11ms/step - loss: 0.3029 - accuracy: 0.8606 - val_loss: 0.5870 - val_accuracy: 0.8571
# Epoch 51/100
# 32/32 [==============================] - 0s 14ms/step - loss: 0.3049 - accuracy: 0.8765 - val_loss: 0.5082 - val_accuracy: 0.8254
# Epoch 52/100
# 32/32 [==============================] - 1s 17ms/step - loss: 0.2826 - accuracy: 0.8924 - val_loss: 0.6444 - val_accuracy: 0.7302
# Epoch 53/100
# 32/32 [==============================] - 0s 10ms/step - loss: 0.3043 - accuracy: 0.8566 - val_loss: 0.5747 - val_accuracy: 0.7778
# Epoch 54/100
# 32/32 [==============================] - 0s 11ms/step - loss: 0.3180 - accuracy: 0.8566 - val_loss: 0.5160 - val_accuracy: 0.7937
# Epoch 55/100
# 32/32 [==============================] - 0s 9ms/step - loss: 0.2957 - accuracy: 0.8685 - val_loss: 0.5240 - val_accuracy: 0.8254
# Epoch 56/100
# 32/32 [==============================] - 0s 10ms/step - loss: 0.2897 - accuracy: 0.8566 - val_loss: 0.4882 - val_accuracy: 0.8254
# Epoch 57/100
# 32/32 [==============================] - 0s 13ms/step - loss: 0.3146 - accuracy: 0.8924 - val_loss: 0.4596 - val_accuracy: 0.7937
# Epoch 58/100
# 32/32 [==============================] - 0s 10ms/step - loss: 0.2872 - accuracy: 0.8884 - val_loss: 0.5253 - val_accuracy: 0.8095
# Epoch 59/100
# 32/32 [==============================] - 0s 12ms/step - loss: 0.3147 - accuracy: 0.8606 - val_loss: 0.5521 - val_accuracy: 0.7778
# Epoch 60/100
# 32/32 [==============================] - 0s 9ms/step - loss: 0.3000 - accuracy: 0.8685 - val_loss: 0.5973 - val_accuracy: 0.8254
# Epoch 61/100
# 32/32 [==============================] - 0s 15ms/step - loss: 0.3006 - accuracy: 0.8765 - val_loss: 0.4846 - val_accuracy: 0.7937
# Epoch 62/100
# 32/32 [==============================] - 0s 10ms/step - loss: 0.2789 - accuracy: 0.8765 - val_loss: 0.5190 - val_accuracy: 0.7778
# Epoch 63/100
# 32/32 [==============================] - 0s 12ms/step - loss: 0.2786 - accuracy: 0.8566 - val_loss: 0.5579 - val_accuracy: 0.8254
# Epoch 64/100
# 32/32 [==============================] - 0s 10ms/step - loss: 0.2702 - accuracy: 0.8805 - val_loss: 0.5787 - val_accuracy: 0.7937
# Epoch 65/100
# 32/32 [==============================] - 0s 11ms/step - loss: 0.3162 - accuracy: 0.8645 - val_loss: 0.6303 - val_accuracy: 0.8413
# Epoch 66/100
# 32/32 [==============================] - 0s 10ms/step - loss: 0.3046 - accuracy: 0.8765 - val_loss: 0.5642 - val_accuracy: 0.7778
# Epoch 67/100
# 32/32 [==============================] - 0s 10ms/step - loss: 0.2872 - accuracy: 0.8645 - val_loss: 0.6426 - val_accuracy: 0.7937
# Epoch 68/100
# 32/32 [==============================] - 0s 11ms/step - loss: 0.2709 - accuracy: 0.8884 - val_loss: 0.6301 - val_accuracy: 0.8095
# Epoch 69/100
# 32/32 [==============================] - 0s 10ms/step - loss: 0.2804 - accuracy: 0.8685 - val_loss: 0.6014 - val_accuracy: 0.8095
# Epoch 70/100
# 32/32 [==============================] - 1s 19ms/step - loss: 0.2739 - accuracy: 0.8725 - val_loss: 0.6152 - val_accuracy: 0.7619
# Epoch 71/100
# 32/32 [==============================] - 0s 15ms/step - loss: 0.2912 - accuracy: 0.8845 - val_loss: 0.6080 - val_accuracy: 0.7937
# Epoch 72/100
# 32/32 [==============================] - 0s 12ms/step - loss: 0.2362 - accuracy: 0.8884 - val_loss: 0.6653 - val_accuracy: 0.8095
# Epoch 73/100
# 32/32 [==============================] - 0s 13ms/step - loss: 0.2584 - accuracy: 0.8884 - val_loss: 0.5959 - val_accuracy: 0.7937
# Epoch 74/100
# 32/32 [==============================] - 0s 10ms/step - loss: 0.2693 - accuracy: 0.8725 - val_loss: 0.7105 - val_accuracy: 0.7937
# Epoch 75/100
# 32/32 [==============================] - 0s 13ms/step - loss: 0.2787 - accuracy: 0.8645 - val_loss: 0.5854 - val_accuracy: 0.8254
# Epoch 76/100
# 32/32 [==============================] - 1s 17ms/step - loss: 0.2573 - accuracy: 0.8805 - val_loss: 0.7496 - val_accuracy: 0.7619
# Epoch 77/100
# 32/32 [==============================] - 0s 12ms/step - loss: 0.2784 - accuracy: 0.8606 - val_loss: 0.5982 - val_accuracy: 0.7778
# Epoch 78/100
# 32/32 [==============================] - 0s 14ms/step - loss: 0.2693 - accuracy: 0.8725 - val_loss: 0.7218 - val_accuracy: 0.8095
# Epoch 79/100
# 32/32 [==============================] - 0s 11ms/step - loss: 0.2490 - accuracy: 0.9004 - val_loss: 0.6293 - val_accuracy: 0.8095
# Epoch 80/100
# 32/32 [==============================] - 1s 22ms/step - loss: 0.2567 - accuracy: 0.8964 - val_loss: 0.6491 - val_accuracy: 0.7937
# Epoch 81/100
# 32/32 [==============================] - 0s 13ms/step - loss: 0.2385 - accuracy: 0.8924 - val_loss: 0.6734 - val_accuracy: 0.7937
# Epoch 82/100
# 32/32 [==============================] - 0s 10ms/step - loss: 0.2634 - accuracy: 0.8845 - val_loss: 0.6597 - val_accuracy: 0.8095
# Epoch 83/100
# 32/32 [==============================] - 0s 12ms/step - loss: 0.2374 - accuracy: 0.9084 - val_loss: 0.6864 - val_accuracy: 0.8095
# Epoch 84/100
# 32/32 [==============================] - 0s 12ms/step - loss: 0.2624 - accuracy: 0.8884 - val_loss: 0.6997 - val_accuracy: 0.8095
# Epoch 85/100
# 32/32 [==============================] - 0s 12ms/step - loss: 0.2355 - accuracy: 0.9004 - val_loss: 0.7633 - val_accuracy: 0.8095
# Epoch 86/100
# 32/32 [==============================] - 0s 10ms/step - loss: 0.2442 - accuracy: 0.8845 - val_loss: 0.7450 - val_accuracy: 0.8095
# Epoch 87/100
# 32/32 [==============================] - 0s 10ms/step - loss: 0.2393 - accuracy: 0.9084 - val_loss: 0.6973 - val_accuracy: 0.8095
# Epoch 88/100
# 32/32 [==============================] - 0s 12ms/step - loss: 0.2392 - accuracy: 0.8964 - val_loss: 0.6319 - val_accuracy: 0.8095
# Epoch 89/100
# 32/32 [==============================] - 0s 12ms/step - loss: 0.2660 - accuracy: 0.8685 - val_loss: 0.6835 - val_accuracy: 0.7937
# Epoch 90/100
# 32/32 [==============================] - 0s 12ms/step - loss: 0.2283 - accuracy: 0.8725 - val_loss: 0.8057 - val_accuracy: 0.8095
# Epoch 91/100
# 32/32 [==============================] - 0s 11ms/step - loss: 0.2590 - accuracy: 0.8765 - val_loss: 0.7412 - val_accuracy: 0.7937
# Epoch 92/100
# 32/32 [==============================] - 0s 15ms/step - loss: 0.2701 - accuracy: 0.8845 - val_loss: 0.7390 - val_accuracy: 0.8095
# Epoch 93/100
# 32/32 [==============================] - 1s 15ms/step - loss: 0.2519 - accuracy: 0.8924 - val_loss: 0.8212 - val_accuracy: 0.7778
# Epoch 94/100
# 32/32 [==============================] - 0s 15ms/step - loss: 0.2640 - accuracy: 0.8884 - val_loss: 0.6626 - val_accuracy: 0.8095
# Epoch 95/100
# 32/32 [==============================] - 0s 12ms/step - loss: 0.2277 - accuracy: 0.9044 - val_loss: 0.7520 - val_accuracy: 0.8095
# Epoch 96/100
# 32/32 [==============================] - 0s 13ms/step - loss: 0.2347 - accuracy: 0.9084 - val_loss: 0.8628 - val_accuracy: 0.8254
# Epoch 97/100
# 32/32 [==============================] - 0s 12ms/step - loss: 0.2415 - accuracy: 0.9044 - val_loss: 0.8559 - val_accuracy: 0.8095
# Epoch 98/100
# 32/32 [==============================] - 0s 13ms/step - loss: 0.2633 - accuracy: 0.8685 - val_loss: 0.8986 - val_accuracy: 0.7619
# Epoch 99/100
# 32/32 [==============================] - 0s 12ms/step - loss: 0.2932 - accuracy: 0.8645 - val_loss: 0.9472 - val_accuracy: 0.7937
# Epoch 100/100
# 32/32 [==============================] - 0s 9ms/step - loss: 0.2714 - accuracy: 0.8765 - val_loss: 0.5661 - val_accuracy: 0.7937
# CPU times: user 1min 58s, sys: 2min 22s, total: 4min 20s
# Wall time: 38.5 s

# %%
# Accuracy plot
plt.plot(history.history["accuracy"])
plt.plot(history.history["val_accuracy"])
plt.title("Model accuracy")
plt.ylabel("accuracy")
plt.legend(["training", "validation"])
plt.xlabel("epoch")
# Out:
# Text(0.5, 0, 'epoch')

# %%
loss, acc = model.evaluate(testFeatures, testLabels, verbose=2)
print("\n Accuracy: ", acc)
# Out:
# 3/3 - 0s - loss: 0.4065 - accuracy: 0.8462 - 30ms/epoch - 10ms/step
#
#  Accuracy:  0.8461538553237915

# %%
predictions = model.predict(testFeatures)
# Out:
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f3f92660180> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 3/3 [==============================] - 0s 3ms/step

# %%
entry = 13 # orice numar intre 0 si 77, reprezinta indexul unui entry din datasetul de antrenare
print("Entry ", entry)
print("Probabilities: ", predictions[entry])
print(f"\nAnswer: {classes[np.argmax(predictions[entry])]} \t Actual: {classes[np.argmax(testLabels[entry])]}")
if np.argmax(predictions[entry]) == np.argmax(testLabels[entry]):
    print("\nPrediction CORRECT")
else:
    print("\nPrediction WRONG")
# Out:
# Entry  13
# Probabilities:  [0.003 0.987 0.01 ]
#
# Answer: MED 	 Actual: MED
#
# Prediction CORRECT
